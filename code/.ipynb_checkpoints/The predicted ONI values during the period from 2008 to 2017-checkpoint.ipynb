f_2014_tru=[-0.4,-0.4,-0.2,0.1,0.3,0.2,0.1,0.0,0.2,0.4,0.6,0.7]

# %%
f_2015_pre=[0.6471787,0.59871853,0.74386575,1.09002976,1.48106207,1.63434431,1.43155453,1.07142175,0.98681175,1.14512161,1.10975078,0.84867126]
f_2015_tru=[0.6,0.6,0.6,0.8,1.0,1.2,1.5,1.8,2.1,2.4,2.5,2.6]

# %%
f_2016_pre=[ 2.25015097,1.96793829,1.39737285,0.83895748,0.4881617,0.27141112,0.10620102,-0.09243051,-0.36919386,-0.66663392,-0.8775558,-0.89634928]
f_2016_tru=[2.5,2.2,1.7,1.0,0.5,0.0,-0.3,-0.6,-0.7,-0.7,-0.7,-0.6]

# %%
f_2017_pre=[-0.41843241,-0.21173347,-0.10744654,0.01122552,0.09052058,0.10752269,0.0299614,-0.11605551,-0.27297099,-0.38896946,-0.43848105,-0.41161876]
f_2017_tru=[-0.3,-0.1,0.1,0.3,0.4,0.4,0.2,-0.1,-0.4,-0.7,-0.9,-1.0]

# %%
pre_all=f_2008_pre+f_2009_pre+f_2010_pre+f_2011_pre+f_2012_pre+f_2013_pre+f_2014_pre+f_2015_pre+f_2016_pre+f_2017_pre

# %%
tru_all=f_2008_tru+f_2009_tru+f_2010_tru+f_2011_tru+f_2012_tru+f_2013_tru+f_2014_tru+f_2015_tru+f_2016_tru+f_2017_tru

# %%
import matplotlib.pyplot as plt
import pandas as pd
import math
import numpy as np
# %matplotlib inline

normalized_lstms=np.array([-1.15227413,-1.12899268,-0.47112679,-0.13396825,0.12515147,0.1437145,0.247545,0.25556532,0.25881884,0.43107274,0.44317427,0.43884516])
predicted_values=np.array([-0.9138631,-0.64577143,-0.46778013,-0.41380659,-0.29520753,-0.01224175,0.26282753,0.38837113,0.51434888,0.69200458,0.78456772,0.7583482])
round_true_values=np.array([-0.9,-0.8,-0.6,-0.4,-0.1,0.1,0.1,0.2,0.4,0.7,0.9,0.8])

plt.figure(figsize=(14,6))
index_start = np.array(range(1,121))
#index_start = ["DJF","JFM","FMA","MAM","AMJ","MJJ","JJA","JAS","ASO","SON","OND","NDJ"]

#plt.title("Actual Values And Predicting Values",fontstyle="italic",fontsize=24)
plt.plot(index_start,np.array(tru_all).reshape(-1),color="blue",marker="x",linestyle='--',label='Observed values')
plt.plot(index_start,np.array(pre_all).reshape(-1),color="red",marker="o",label='Predicted values')

plt.tick_params(labelsize=14)


plt.xlabel('Time (Months)',fontsize=14,color="black")
plt.ylabel('ONI (℃)',fontsize=14,color="black")

plt.legend(loc=2,fontsize=12) 

plt.show()
